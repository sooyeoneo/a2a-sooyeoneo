# %% [markdown]
# #### Vector Store (벡터 DB 저장)
#
# * 임베딩된 청크/문서 저장 : FAISS, Chroma, Pinecone 등 선택 가능
# * 예시 : FAISS (필요한 벡터 DB로 변경 가능)
#
# * 의미기반 검색(semantic search) 및 빠른 응답 속도 보장

# %%
from langchain_community.vectorstores import FAISS

vectorstore = FAISS.from_documents(documents=docs, embedding=embeddings)

# %% [markdown]
# #### LangSmith 추적 연동 설정 코드
#
# * 이 셀은 실행만 하고, 내용을 수정하거나 해석할 필요가 없음
#
# * Jupyter Notebook에서 출력 숨기기
#     * `%%capture` 매직커맨드 사용하면 실행 결과만 숨김
#     (코드는 노출 : 문서화 할 땐 nbconvert로 markdown/pdf로 export 후 해당 셀 삭제하면 코드 안 보임)

# %%
import os
from dotenv import load_dotenv

def init_env_and_langsmith(project_name="LEADSCOUT", tracing=True):
    load_dotenv()
    os.environ["LANGCHAIN_TRACING_V2"] = "true" if tracing else "false"
    os.environ["LANGCHAIN_API_KEY"] = os.getenv("LANGSMITH_API_KEY")
    os.environ["LANGCHAIN_PROJECT"] = "LEADSCOUT"

def print_langsmith_status():
    tracing = os.getenv("LANGCHAIN_TRACING_V2", "").lower()
    if tracing == "true":
        print("LangSmith 추적을 시작합니다.")
    else:
        print("LangSmith 추적을 하지 않습니다.")

def handle_langsmith_env_error():
    if not os.getenv("LANGCHAIN_API_KEY"):
        raise EnvironmentError("LANGSMITH_API_KEY가 .env에 없거나 잘못되었습니다.")

# %% [markdown]
# #### LangSmith & 모니터링
# * `.env` 설정으로 LangSmith Trance 활성화
#
# * 토큰, 비용, 프롬프트, 응답 품질 등 실시간 대시보드 제공 (LangChain 공식 문서 및 LangSmith 대시보드 참고)

# %%
init_env_and_langsmith(project_name="LEADSCOUT", tracing=True)
handle_langsmith_env_error()
print_langsmith_status()

from langchain_openai import ChatOpenAI

llm = ChatOpenAI(model="gpt-4o")
result = llm.invoke("삼성전자 소개해줘")
print(result)
# Out:
# LangSmith 추적을 시작합니다.
# content='삼성전자는 대한민국을 대표하는 글로벌 전자 기업으로, 삼성 그룹의 계열사 중 하나입니다. 1969년에 설립되었으며, 본사는 경기도 수원시에 위치하고 있습니다. 삼성전자는 소비자 가전, 정보통신, 반도체, 디스플레이 등 다양한 사업 분야에서 활동하고 있습니다. 주요 제품으로는 스마트폰, TV, 반도체 칩, 가전제품 등이 있습니다.\n\n삼성전자는 혁신적인 기술 개발과 대규모 생산 역량을 바탕으로 글로벌 시장에서 중요한 위치를 차지하고 있습니다. 특히, 스마트폰 시장에서는 갤럭시 시리즈를 통해 큰 성공을 거두었고, 반도체 부문에서는 메모리 칩과 시스템 반도체 분야에서 세계적인 선두주자입니다.\n\n회사는 지속 가능한 경영을 목표로 하며, 친환경 제품 개발과 사회적 책임에도 많은 노력을 기울이고 있습니다. 글로벌 경영 네트워크를 통해 다양한 국가에서 사업을 운영하고 있으며, 전 세계 수많은 고객들에게 제품과 서비스를 제공하고 있습니다.' additional_kwargs={'refusal': None} response_metadata={'token_usage': {'completion_tokens': 234, 'prompt_tokens': 13, 'total_tokens': 247, 'completion_tokens_details': {'accepted_prediction_tokens': 0, 'audio_tokens': 0, 'reasoning_tokens': 0, 'rejected_prediction_tokens': 0}, 'prompt_tokens_details': {'audio_tokens': 0, 'cached_tokens': 0}}, 'model_name': 'gpt-4o-2024-08-06', 'system_fingerprint': 'fp_07871e2ad8', 'id': 'chatcmpl-BlWdz8dVb2a5rEeTBVs9rQIB1cATN', 'service_tier': 'default', 'finish_reason': 'stop', 'logprobs': None} id='run--d4579a16-dcfa-430a-a59f-4ee9dbd37f8c-0' usage_metadata={'input_tokens': 13, 'output_tokens': 234, 'total_tokens': 247, 'input_token_details': {'audio': 0, 'cache_read': 0}, 'output_token_details': {'audio': 0, 'reasoning': 0}}

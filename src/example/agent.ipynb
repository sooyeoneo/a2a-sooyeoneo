# %% [markdown]
# #### LLM (대형 언어모델)
#
# * OpenAI GPT-4o, GPT-3.5, Anthropic Claude 등 연결
# * .env 기반 자동 인증
#
# * LangSmith 연동 : 실행 trace, 토큰/비용/프롬프트 분석 지원

# %%
from langchain_openai import ChatOpenAI
llm = ChatOpenAI(model_name="gpt-4o")

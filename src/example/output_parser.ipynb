# %% [markdown]
# #### Chain (전체 파이프라인 연결)
#
# * 모든 단계를 하나의 체인으로 묶어 실행
# * LCEL or LangChain Runnable 방식
#
# * 결과 : OutputParser로 구조화된 JSON/Python 객체로 변환 가능

# %%
from langchain.chains import LLMChain

chain = LLMChain(
    llm=llm,
    prompt=prompt,
    retriever=retriever
)    

response = chain.invoke({"question" : "삼성전자의 2023년도 매출은?"})
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 from langchain.chains import LLMChain
#       3 chain = LLMChain(
# ----> 4     llm=llm,
#       5     prompt=prompt,
#       6     retriever=retriever
#       7 )
#       9 response = chain.invoke({"question" : "삼성전자의 2023년도 매출은?"})
#
# NameError: name 'llm' is not defined

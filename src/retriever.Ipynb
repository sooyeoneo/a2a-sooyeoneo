# %% [markdown]
# #### Retriever (검색기)
#
# * 사용자의 질문(쿼리) 벡터화 -> 유사도 높은 청크 추출 (Dense/Sparse 가능)
# * Dense Retriever 가 RAG에서 기본
#
# * BM25 등 Sparse 방법도 선택 가능 (비교 연구 추천)

# %%
retriever = vectorstore.as_retriever()

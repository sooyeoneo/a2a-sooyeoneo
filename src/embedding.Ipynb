# %% [markdown]
# #### Embedding (임베딩 생성)
# * OpenAI, sentence-transformers 등 백터화
# * 임베딩 결과는 추후 벡터 DB에 저장됨
#
# * 임베딩은 텍스트를 수치형 벡터로 변환해 의미 기반 유사도 검색을 가능하게 함

# %%
from langchain_openai import OpenAIEmbeddings

Embeddings = OpenAIEmbeddings()

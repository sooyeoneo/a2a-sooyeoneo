# %%
# 실행 순서

# 첫 번째 실행 (테스트)
python src/run/run_web_crawling_rag.py "삼성전자" --verbose

#결과 확인
ls -la src/generated_reports/

#HTML 보고서 생성
python src/generator/report_generator.py

#브라우저에서 확인
open src/generator/company_report.html

# %% [markdown]
# #### 1. 환경 설정 확인
# * OpenAI API 키 설정 (필수)
# * export OPENAI_API_KEY="your-openai-api-key-here"
#
# #### LangSmith API 키 설정 (선택적, 추적용)
# * export LANGSMITH_API_KEY="your-langsmith-api-key-here"
#
# #### 2. 의존성 설치 확인
# * 필요한 패키지들이 모두 설치되어 있는지 확인
# * pip install -r requirements.txt
#
# * 또는 최소 버전으로 설치
# * pip install -r requirements-mini.txt
# * 필요한 패키지들이 모두 설치되어 있는지 확인
#
# #### 3. 웹크롤링 RAG 파이프라인 실행
# * 기본 실행 (삼성전자)
# * python src/run/run_web_crawling_rag.py "삼성전자"
#
# * 다른 회사로 실행
# * python src/run/run_web_crawling_rag.py "네이버"
# * python src/run/run_web_crawling_rag.py "카카오"
#
# * 상세 로그와 함께 실행
# * python src/run/run_web_crawling_rag.py "삼성전자" --verbose
#
# * 커스텀 출력 디렉토리로 실행
# * python src/run/run_web_crawling_rag.py "삼성전자" --output-dir "custom_reports"
#
# #### 4. 향상된 RAG 파이프라인 실행
#
# * 기본 실행
# * python src/run/run_enhanced_rag.py "삼성전자"
#
# #### 상세 로그와 함께 실행
# * python src/run/run_enhanced_rag.py "삼성전자" --
#
# #### 5. HTML 보고서 생성
#
# * 기본 HTML 보고서 생성
# * python src/generator/report_generator.py
#
# * 웹 검색 기반 고급 보고서 생성
# * python src/generator/web_report_agent.py

# %% [markdown]
# ### 🖥️ 실제 실행
#
# * `python src/run_enhanced_rag.py`

# %% [markdown]
# ### ⚙️ 실행 명령어
#
# * 기본 실행
#     * `python src/run_enhanced_rag.py`
#
# * 특정 회사 분석
#     * `python src/run_enhanced_rag.py --company "삼성전자"`
#
# * 특정 필드만 검색
#     * `python src/run_enhanced_rag.py --fields 대표자 매출액 직원수`
#
# * 다른 데이터 파일 사용
#     * `python src/run_enhanced_rag.py --data-file "path/to/your/company_data.json"`
#
# * OpenAI API 키 지정
#     * `python src/run_enhanced_rag.py --openai-key "your-openai-api-key"`
#
# * 결과 저장 위치 변경
#     * `python src/run_enhanced_rag.py --output "my_reports"`
#
# * 모든 옵션 조합
#     * `python src/run_enhanced_rag.py \`
#         `--company "삼성전자" \`
#         `--fields 대표자 매출액 직원수 설립년도 \`
#         `--output "custom_reports" \`
#         `--openai-key "your-key"`
#
# * 도움말 보기
#     * `python src/run_enhanced_rag.py --help`

# %% [markdown]
# ### 📟 웹크롤링 기반 RAG 파이프라인 실행
# python run_web_crawling_rag.py "삼성전자"
#
# * 상세 로그와 함께 실행
#     * python run_web_crawling_rag.py "네이버" --verbose
#
# * 테스트 실행
#     * python test_web_crawling_rag.py

# %% [markdown]
# ### 🎛️ 테스트 실행
#
# * `python src/test/test_enhanced_rag_pipeline.py`
#
# * `python src/test/test_html_report_generator.py`
#
# * `python src/test/test_web_report_agent.py`
